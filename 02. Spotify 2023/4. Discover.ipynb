# %%
import pandas as pd

# %%
df = pd.read_csv('data/spotify_2023_clean.csv', encoding='latin-1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_name         953 non-null    object
#  1   artist             953 non-null    object
#  2   featuring_artists  366 non-null    object
#  3   artist_count       953 non-null    int64
#  4   streams            953 non-null    int64
#  5   bpm                953 non-null    int64
#  6   key                858 non-null    object
#  7   mode               953 non-null    object
#  8   danceability       953 non-null    int64
#  9   valence            953 non-null    int64
#  10  energy             953 non-null    int64
#  11  acousticness       953 non-null    int64
#  12  instrumentalness   953 non-null    int64
#  13  liveness           953 non-null    int64
#  14  speechiness        953 non-null    int64
#  15  released_date      953 non-null    object
# ...

# %%
df.head()
# Out:
#                             track_name          artist featuring_artists  \
# 0  Seven (feat. Latto) (Explicit Ver.)           Latto         Jung Kook
# 1                                 LALA     Myke Towers               NaN
# 2                              vampire  Olivia Rodrigo               NaN
# 3                         Cruel Summer    Taylor Swift               NaN
# 4                       WHERE SHE GOES       Bad Bunny               NaN
#
#    artist_count    streams  bpm key   mode  danceability  valence  energy  \
# 0             2  141381703  125   B  Major            80       89      83
# 1             1  133716286   92  C#  Major            71       61      74
# 2             1  140003974  138   F  Major            51       32      53
# 3             1  800840817  170   A  Major            55       58      72
# 4             1  303236322  144   A  Minor            65       23      80
#
#    acousticness  instrumentalness  liveness  speechiness released_date
# ...

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# **Stream values hard to read**

# %%
df['streams'] = df['streams'].astype(float)
pd.options.display.float_format = '{:,.0f}'.format

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 1. 15 most listened songs

# %%
df.sort_values(by='streams', ascending=False).head(15)[['track_name', 'artist', 'streams']]
# Out:
#                                         track_name            artist  \
# 55                                 Blinding Lights        The Weeknd
# 179                                   Shape of You        Ed Sheeran
# 86                               Someone You Loved     Lewis Capaldi
# 620                                   Dance Monkey       Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse       Post Malone
# 162                                      One Dance             Drake
# 84                       STAY (with Justin Bieber)     Justin Bieber
# 140                                       Believer   Imagine Dragons
# 725                                         Closer  The Chainsmokers
# 48                                         Starboy        The Weeknd
# 138                                        Perfect        Ed Sheeran
# 71                                      Heat Waves     Glass Animals
# 14                                       As It Was      Harry Styles
# ...

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 2. 10 least listened songs

# %%
df.sort_values(by='streams').head(10)[['track_name', 'artist', 'streams']]
# Out:
#                                             track_name         artist  \
# 144                                              QUEMA            Sog
# 142                        Gol Bolinha, Gol Quadrado 2    Mc Pedrinho
# 68                                           Overdrive    Post Malone
# 58                                                 S91        Karol G
# 30                                                Rush    Troye Sivan
# 248                     Danger (Spider) (Offset & JID)         Offset
# 104                                          New Jeans       NewJeans
# 193             Better Than Revenge (Taylor's Version)   Taylor Swift
# 17   What Was I Made For? [From The Motion Picture ...  Billie Eilish
# 150                                     Mi Bello Angel  Natanael Cano
#
#        streams
# 144 11,599,388
# 142 11,956,641
# 68  14,780,425
# 58  16,011,326
# 30  22,581,161
# 248 24,975,653
# 104 29,562,220
# 193 30,343,206
# 17  30,546,883
# 150 31,873,544

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 3. The top 5 songs with the lowest valence

# %%
df.sort_values(by='valence').head(5)[['track_name', 'artist', 'streams', 'valence']]
# Out:
#                        track_name        artist     streams  valence
# 487                        Maroon  Taylor Swift 317,726,339        4
# 914                       Selfish      PnB Rock 380,319,238        4
# 242               Just Wanna Rock  Lil Uzi Vert 457,184,829        4
# 408                    After Dark      Mr.Kitty 646,886,885        4
# 670  Down Under (feat. Colin Hay)         Luude 252,871,192        4

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 4. The top 5 songs with the highest energy and order by streams

# %%
df.sort_values(by=['energy', 'streams'], ascending=False).head(5)[['track_name', 'artist', 'streams', 'energy']]
# df.sort_values(by=['energy', 'valece'], ascending=False).head(5)[['track_name', 'artist', 'streams', 'energy']]
# Out:
#                                 track_name             artist       streams  \
# 42                         I'm Good (Blue)         Bebe Rexha 1,109,433,169
# 319                      Murder In My Mind           Kordhell   448,843,705
# 795  That That (prod. & feat. SUGA of BTS)                PSY   212,109,195
# 60                             TÃ¯Â¿Â½Ã¯Â¿             dennis   111,947,664
# 367                  Bombonzinho - Ao Vivo  Israel & Rodolffo   263,453,310
#
#      energy
# 42       97
# 319      97
# 795      96
# 60       96
# 367      95

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### # 5. The 10 most listened to songs, sung by more than one artist together, order by danceability

# %%
# df.sort_values(by=['streams', 'danceability'], ascending=False).head(10)
top_df = df.sort_values(by='streams', ascending=False).head(10)
top_df.sort_values(by='danceability', ascending=False)[['track_name', 'artist', 'streams', 'danceability']]
# Out:
#                                         track_name            artist  \
# 179                                   Shape of You        Ed Sheeran
# 620                                   Dance Monkey       Tones and I
# 162                                      One Dance             Drake
# 140                                       Believer   Imagine Dragons
# 41   Sunflower - Spider-Man: Into the Spider-Verse       Post Malone
# 725                                         Closer  The Chainsmokers
# 48                                         Starboy        The Weeknd
# 84                       STAY (with Justin Bieber)     Justin Bieber
# 55                                 Blinding Lights        The Weeknd
# 86                               Someone You Loved     Lewis Capaldi
#
#           streams  danceability
# 179 3,562,543,890            83
# 620 2,864,791,672            82
# 162 2,713,922,350            77
# 140 2,594,040,133            77
# 41  2,808,096,550            76
# ...

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 6. Songs with the most people singing along

# %%
filt = df['artist_count'] == df['artist_count'].max()
df[filt][['track_name', 'artist', 'streams', 'artist_count']]
# Out:
#           track_name    artist     streams  artist_count
# 35   Los del Espacio   Big One 123,122,413             8
# 642         Se Le Ve  Arcangel 223,319,934             8

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 7. Taylor Swift's numer of songs (excluding songs feturing Taylor)

# %%
# df[df['artist'] == 'Taylor Swift'].shape[0]
(df['artist'] == 'Taylor Swift').sum()
# Out:
# 36

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 8. Featuring by Taylor Swift

# %%
# df[df['featuring_artists'].str.contains('Taylor Swift')].shape[0]    # ERROR because of NaN values
df['featuring_artists'] = df['featuring_artists'].fillna('-')
mask = df['featuring_artists'].str.contains('Taylor Swift')    # might be with someone else in same cell
# mask = df['featuring_artists'].str.contains('Peso Pluma')    # try this
df[mask][['track_name', 'artist', 'featuring_artists', 'streams']]
# Out:
#                                        track_name        artist  \
# 223   Snow On The Beach (feat. More Lana Del Rey)  Lana Del Rey
# 652  The Joker And The Queen (feat. Taylor Swift)    Ed Sheeran
#
#     featuring_artists     streams
# 223      Taylor Swift  60,350,538
# 652      Taylor Swift 146,789,379

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 9. Total number of songs which Taylor Swift is in

# %%
# own = df[df['artist'] == 'Taylor Swift'].shape[0]
own = df[df['artist'] == 'Taylor Swift']


df['featuring_artists'] = df['featuring_artists'].fillna('-')
mask = df['featuring_artists'].str.contains('Taylor Swift')
# feat = df[mask].shape[0]
feat = df[mask]


# own + feat
pd.concat([own, feat]).shape[0]
# Out:
# 38

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 10. 5 of Taylor Swift's most listend songs

# %%
ts_df = df[df['artist'] == 'Taylor Swift']
ts_df.sort_values(by='streams', ascending=False)[['track_name', 'artist', 'streams']].head(5)
# Out:
#        track_name        artist       streams
# 37    Blank Space  Taylor Swift 1,355,959,075
# 176  Shake It Off  Taylor Swift 1,113,838,873
# 33      Anti-Hero  Taylor Swift   999,748,277
# 100         Lover  Taylor Swift   882,831,184
# 59       cardigan  Taylor Swift   812,019,557

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 11. Taylor Swift's average listening

# %%
average = df[df['artist'] == 'Taylor Swift']['streams'].mean()
print(f"{average:,.0f}")
# Out:
# 400,645,507

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 12. Taylor Swift's total listening

# %%
total = df[df['artist'] == 'Taylor Swift']['streams'].sum()
print(f"{total:,.0f}")
# Out:
# 14,423,238,266

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 13. Taylor Swift's songs with more listens than the average numer of listens of her own songs

# %%
ts_df = df[df['artist'] == 'Taylor Swift']
filt = ts_df['streams'] > ts_df['streams'].mean()
ts_df[filt][['track_name', 'artist', 'streams']]
# Out:
#                                             track_name        artist  \
# 3                                         Cruel Summer  Taylor Swift
# 33                                           Anti-Hero  Taylor Swift
# 37                                         Blank Space  Taylor Swift
# 38                                               Style  Taylor Swift
# 59                                            cardigan  Taylor Swift
# 66                                               Karma  Taylor Swift
# 93                           DonÃ¯Â¿Â½Ã¯Â¿Â½Ã¯Â¿Â½t Bl  Taylor Swift
# 100                                              Lover  Taylor Swift
# 119                                             august  Taylor Swift
# 163                                          Enchanted  Taylor Swift
# 176                                       Shake It Off  Taylor Swift
# 237                                      Lavender Haze  Taylor Swift
# 314                                      Midnight Rain  Taylor Swift
# ...

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 14. Taylor Swift's songs with more listens than the average numer of listens of entire list

# %%
ts_df = df[df['artist'] == 'Taylor Swift']
filt = ts_df['streams'] > df['streams'].mean()
ts_df[filt][['track_name', 'artist', 'streams']]
# Out:
#                                             track_name        artist  \
# 3                                         Cruel Summer  Taylor Swift
# 33                                           Anti-Hero  Taylor Swift
# 37                                         Blank Space  Taylor Swift
# 38                                               Style  Taylor Swift
# 59                                            cardigan  Taylor Swift
# 93                           DonÃ¯Â¿Â½Ã¯Â¿Â½Ã¯Â¿Â½t Bl  Taylor Swift
# 100                                              Lover  Taylor Swift
# 119                                             august  Taylor Swift
# 163                                          Enchanted  Taylor Swift
# 176                                       Shake It Off  Taylor Swift
# 537  All Too Well (10 Minute Version) (Taylor's Ver...  Taylor Swift
#
#           streams
# 3     800,840,817
# 33    999,748,277
# 37  1,355,959,075
# 38    786,181,836
# 59    812,019,557
# 93    685,032,533
# ...

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 15- Unique artists list

# %%
uniques = df['artist'].unique()
pd.DataFrame(uniques)
# df['artist'].nunique()
# Out:
#                     0
# 0               Latto
# 1         Myke Towers
# 2      Olivia Rodrigo
# 3        Taylor Swift
# 4           Bad Bunny
# ..                ...
# 454       Rosa Walton
# 455        MC Ryan SP
# 456  Ludwig Goransson
# 457               Jin
# 458      Selena Gomez
#
# [459 rows x 1 columns]

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# **Change type to date**

# %%
df['released_date'] = pd.to_datetime(df['released_date'])

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 16. 5 newest songs

# %%
# df['released_date'].max() # single result
df.nlargest(5, 'released_date')[['track_name', 'artist', 'streams', 'released_date']]
# Out:
#                                            track_name         artist  \
# 0                 Seven (feat. Latto) (Explicit Ver.)          Latto
# 58                                                S91        Karol G
# 68                                          Overdrive    Post Malone
# 17  What Was I Made For? [From The Motion Picture ...  Billie Eilish
# 30                                               Rush    Troye Sivan
#
#        streams released_date
# 0  141,381,703    2023-07-14
# 58  16,011,326    2023-07-14
# 68  14,780,425    2023-07-14
# 17  30,546,883    2023-07-13
# 30  22,581,161    2023-07-13

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 17. 5 oldest songs

# %%
# df['released_date'].min() # single result
df.nsmallest(5, 'released_date')[['track_name', 'artist', 'streams', 'released_date']]
# Out:
#                                             track_name         artist  \
# 439                              Agudo MÃ¯Â¿Â½Ã¯Â¿Â½gi          Styrx
# 469                                    White Christmas    Bing Crosby
# 460  The Christmas Song (Merry Christmas To You) - ...  Nat King Cole
# 466             Let It Snow! Let It Snow! Let It Snow!  Frank Sinatra
# 459           A Holly Jolly Christmas - Single Version      Burl Ives
#
#         streams released_date
# 439  90,598,517    1930-01-01
# 469 395,591,396    1942-01-01
# 460 389,771,964    1946-11-01
# 466 473,248,298    1950-01-01
# 459 395,591,396    1952-01-01

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 18. Songs released between 2000 and 2007

# %%
start_date = pd.to_datetime('2000-01-01')
end_date = pd.to_datetime('2007-01-01')
filt = (df['released_date'] >= start_date) & (df['released_date'] <= end_date)
df[filt][['track_name', 'artist', 'streams', 'released_date']].sort_values(by='released_date')
# Out:
#                                             track_name          artist  \
# 250                                The Real Slim Shady          Eminem
# 911                                             Sparks        Coldplay
# 358                                         In The End     Linkin Park
# 477                           My Only Wish (This Year)  Britney Spears
# 143                                         Without Me          Eminem
# 296                 Lose Yourself - Soundtrack Version          Eminem
# 658                                         In Da Club         50 Cent
# 297                                           Superman          Eminem
# 640                                   'Till I Collapse          Eminem
# 910                                      The Scientist        Coldplay
# 331                                               Numb     Linkin Park
# 630                                     Mr. Brightside     The Killers
# ...

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 19. Top 3 of most listened songs in 2023

# %%
start_date = pd.to_datetime('2023-01-01')
filt = (df['released_date'] >= start_date)
df[filt].nlargest(3, 'streams')[['track_name', 'artist', 'streams', 'released_date']]
# Out:
#                                 track_name          artist       streams  \
# 12                                 Flowers     Miley Cyrus 1,316,855,716
# 6                          Ella Baila Sola  Eslabon Armado   725,980,112
# 133  Shakira: Bzrp Music Sessions, Vol. 53         Shakira   721,975,598
#
#     released_date
# 12     2023-01-12
# 6      2023-03-16
# 133    2023-01-11

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 20. Average of characteristic features of 50 most listened songs

# %%
df.nlargest(50, 'streams').loc[:,'danceability':'speechiness'].describe()
# Out:
#        danceability  valence  energy  acousticness  instrumentalness  \
# count            50       50      50            50                50
# mean             61       48      61            31                 0
# std              15       23      17            29                 0
# min              33        6      26             0                 0
# 25%              50       31      50             4                 0
# 50%              61       48      60            26                 0
# 75%              75       63      73            52                 0
# max              91       93      93            93                 2
#
#        liveness  speechiness
# count        50           50
# mean         16            8
# std           9            9
# min           5            2
# 25%           9            4
# 50%          11            5
# 75%          21            8
# max          38           44

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 21. Average of characteristic features of all songs

# %%
df.loc[:,'danceability':'speechiness'].describe()
# Out:
#        danceability  valence  energy  acousticness  instrumentalness  \
# count           953      953     953           953               953
# mean             67       51      64            27                 2
# std              15       23      17            26                 8
# min              23        4       9             0                 0
# 25%              57       32      53             6                 0
# 50%              69       51      66            18                 0
# 75%              78       70      77            43                 0
# max              96       97      97            97                91
#
#        liveness  speechiness
# count       953          953
# mean         18           10
# std          14           10
# min           3            2
# 25%          10            4
# 50%          12            6
# 75%          24           11
# max          97           64

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 22. 5 most present artist as a featuring artist

# %%
temp_df = df['featuring_artists'].str.split(', ', expand=True)
temp_df.replace('-', pd.NA, inplace=True)    # Do not count '-' values

# pd.DataFrame(temp_df[0].unique())          # for col in columns
# pd.DataFrame(temp_df.stack().unique())
pd.DataFrame(temp_df.stack().value_counts().nlargest(5))
# Out:
#                 count
# Bad Bunny          14
# Metro Boomin       13
# 21 Savage          13
# Peso Pluma         11
# Rauw Alejandro      7

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 23. Number of songs sung by single artist

# %%
(df['artist_count'] == 1).sum()
# Out:
# 587

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 24. Number of unique artists

# %%
# len(df['artist'].unique())
df['artist'].unique().shape[0]
# Out:
# 459

# %% [markdown]
# <p style="background-image: linear-gradient(to right, #0D9276, #41b675)"> &nbsp </p>

# %% [markdown]
# #### 25. Years that Taylor Swift release a song

# %%
ts = df[df['artist']=='Taylor Swift']
released_years = pd.DataFrame((ts['released_date'].dt.year).unique())
released_years.rename(columns={0:'years'}, inplace=True)
released_years.sort_values(by='years', inplace=True)
released_years.reset_index(inplace=True, drop=True)     # drop old indexes
released_years.index += 1                               # start with index 1 
released_years.T
# Out:
#           1     2     3     4     5     6     7     8     9
# years  2010  2012  2014  2017  2019  2020  2021  2022  2023
